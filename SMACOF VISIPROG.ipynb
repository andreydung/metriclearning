# %%
from visiprog.data import *
from visiprog.drawing import *
# %matplotlib inline

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn.metrics import euclidean_distances

# %% [markdown]
# Now we will apply this algorithm to ViSiProg data, on a subset of materials (19 and 20).

# %%
groups, N = readVSPLabel()
S = count_matrix(groups, N)
listImg = readImgList()

# %% [markdown]
# Select material 19 and 20

# %%
selection = np.array(list(range(1485,1667)))
S_short = S[selection,:][:,selection]
listImg_short = [listImg[p] for p in selection]

print(S_short.shape)
print(len(listImg_short))
# Out:
# (182, 182)
# 182

# %% [markdown]
# Convert the similarity to distance matrix. Note that missing entries are filled in with zero

# %%
D, nonZeroIndex = similarity_to_distance(S_short, missing_value=0)

D = D/D.max()

# %% [markdown]
# Running the SMACOF (stress majorization) algorithm. This is one version of MDS that could handle missing data.

# %%
X = SMACOF(D, num_iter=100, eps=1e-5)
# Out:
# it: 0, stress 109.260903042
# it: 0, stress 182.851253226
# it: 0, stress 167.146202556
# it: 0, stress 121.520365565
# it: 0, stress 140.208442006
# it: 0, stress 177.971763964
# it: 0, stress 116.171365813
# it: 0, stress 177.79899109
# it: 1, stress 28.583139283
# it: 1, stress 25.4826315226
# it: 1, stress 28.3307568104
# it: 1, stress 35.2431948058
# it: 1, stress 27.1695113672
# it: 1, stress 38.9560818458
# it: 2, stress 28.1640764403
# it: 1, stress 27.0082332051
# it: 2, stress 26.9221964505
# it: 2, stress 34.8001973401
# it: 1, stress 28.9842655403
# it: 3, stress 27.7765189818
# it: 3, stress 34.4064794307
# it: 2, stress 25.1815713999
# it: 2, stress 38.854765376
# it: 2, stress 27.8692414052
# it: 2, stress 26.5688070585
# it: 3, stress 27.428653835
# it: 4, stress 27.4221248296
# it: 3, stress 24.8978901473
# it: 3, stress 26.6934367964
# it: 2, stress 28.4933264941
# it: 4, stress 34.058473603
# it: 3, stress 38.817305267
# it: 4, stress 27.0078008113
# it: 3, stress 26.1536942388
# it: 5, stress 33.75480944
# it: 4, stress 38.8337964018
# it: 4, stress 26.4812726449
# it: 5, stress 27.1022917963
# it: 3, stress 28.0364697115
# it: 5, stress 26.6054311071
# it: 6, stress 26.8167123256
# it: 4, stress 24.630282664
# it: 6, stress 33.4944508909
# breaking at iteration 4 with stress 38.8337964018
# it: 4, stress 25.7615318791
# it: 7, stress 26.5641731204
# it: 6, stress 26.2203242185
# it: 5, stress 25.3910816011
# it: 4, stress 27.609575491
# it: 5, stress 26.2839052292
# it: 8, stress 26.3431185093
# it: 7, stress 25.8513475504
# it: 7, stress 33.274801127
# it: 5, stress 24.3774466101
# it: 6, stress 25.0413143071
# it: 9, stress 26.151905258
# it: 8, stress 33.0914172687
# it: 6, stress 26.0998569131
# it: 5, stress 27.208425238
# it: 8, stress 25.4974978537
# it: 9, stress 32.9390493023
# it: 6, stress 24.1381440565
# it: 10, stress 25.9889224349
# it: 7, stress 24.7113221424
# it: 6, stress 26.8292212201
# it: 7, stress 25.9278989657
# it: 10, stress 32.8126699989
# it: 11, stress 25.8526483515
# it: 9, stress 25.1579337135
# it: 7, stress 26.4692227631
# it: 12, stress 25.7416724336
# it: 10, stress 24.831998068
# it: 8, stress 24.4002918388
# it: 11, stress 32.7079605099
# it: 13, stress 25.6546970214
# it: 7, stress 23.9112228058
# it: 11, stress 24.5192253519
# it: 14, stress 25.5905296434
# it: 8, stress 25.7669415402
# it: 8, stress 26.1274459694
# it: 12, stress 32.6213995477
# it: 9, stress 25.6164699743
# it: 9, stress 25.8038650507
# it: 15, stress 25.548073027
# it: 8, stress 23.695624633
# it: 13, stress 32.5501842104
# it: 9, stress 24.1074759377
# it: 12, stress 24.2193283014
# it: 10, stress 25.4759830484
# it: 10, stress 25.4982322139
# it: 13, stress 23.9321643278
# it: 14, stress 32.4921076262
# it: 16, stress 25.5263168317
# it: 10, stress 23.8321665449
# it: 11, stress 25.3449396911
# it: 14, stress 23.6576875715
# it: 15, stress 32.4454418679
# it: 9, stress 23.4903881767
# it: 11, stress 23.5736750104
# it: 17, stress 25.5243323668
# it: 12, stress 23.3313185841
# breaking at iteration 17 with stress 25.5243323668
# it: 15, stress 23.3958964814
# it: 11, stress 25.2097922789
# it: 13, stress 23.1044134093
# it: 16, stress 32.4088402385
# it: 12, stress 24.9374779697
# it: 12, stress 25.2227565454
# it: 10, stress 23.2946487922
# it: 11, stress 23.1076359825
# it: 17, stress 32.3812606962
# it: 13, stress 24.6801096253
# it: 16, stress 23.1467865073
# it: 13, stress 25.1088614103
# it: 12, stress 22.9286685816
# it: 14, stress 22.8922723904
# it: 14, stress 24.4365095183
# it: 14, stress 25.0027464193
# it: 18, stress 32.3619083732
# it: 17, stress 22.9103145062
# it: 19, stress 32.3501941458
# it: 13, stress 22.7571479096
# it: 20, stress 32.3457060367
# it: 14, stress 22.5925493355
# it: 15, stress 24.205556638
# it: 15, stress 24.9038223626
# it: 18, stress 22.6863777862
# it: 21, stress 32.3481902866
# it: 15, stress 22.6942063174
# it: 16, stress 23.9862100415
# it: 16, stress 24.81152023
# it: 19, stress 22.4748075971
# it: 22, stress 32.3575390388
# it: 16, stress 22.5095268584
# it: 15, stress 22.4344128841
# it: 17, stress 22.3375503803
# it: 17, stress 23.7775172163
# it: 23, stress 32.3737816777
# it: 20, stress 22.2753746521
# breaking at iteration 23 with stress 32.3737816777
# it: 17, stress 24.7253029206
# it: 16, stress 22.2823335975
# it: 18, stress 23.5786159075
# it: 18, stress 24.6446656026
# it: 18, stress 22.177601908
# it: 17, stress 22.1359522977
# it: 21, stress 22.0878028607
# it: 22, stress 21.91178673
# it: 19, stress 24.5691338829
# it: 19, stress 22.0290188054
# it: 18, stress 21.9949472238
# it: 19, stress 23.3887369899
# it: 20, stress 21.8911539562
# it: 23, stress 21.7470079208
# it: 21, stress 21.7633783555
# it: 19, stress 21.8590267921
# it: 24, stress 21.5931474203
# it: 20, stress 21.7279235121
# it: 20, stress 23.2072463092
# it: 25, stress 21.4498916741
# it: 21, stress 23.0335570841
# it: 20, stress 24.4982610808
# it: 22, stress 21.6450830946
# it: 23, stress 21.535680771
# it: 21, stress 21.6013888895
# it: 26, stress 21.316933191
# it: 21, stress 24.4316253009
# it: 27, stress 21.1939676778
# it: 22, stress 22.8671324908
# it: 28, stress 21.0806901562
# it: 22, stress 21.4791889523
# it: 29, stress 20.9765313172
# it: 22, stress 24.3688266757
# it: 30, stress 20.8761490472
# it: 24, stress 21.434606373
# it: 31, stress 20.7806011164
# it: 32, stress 20.6896988584
# it: 23, stress 21.3610997758
# it: 23, stress 24.309484936
# it: 24, stress 21.2469018821
# it: 24, stress 24.2532373591
# it: 25, stress 21.3413176958
# it: 25, stress 21.1363712902
# it: 33, stress 20.6031972235
# it: 23, stress 22.7075116438
# it: 26, stress 21.2552953477
# it: 25, stress 24.1997371079
# it: 27, stress 21.1760423934
# it: 26, stress 24.1486519906
# it: 26, stress 21.0292624001
# it: 34, stress 20.5208513778
# it: 24, stress 22.5542982094
# it: 27, stress 24.0996637099
# it: 28, stress 21.1030836773
# it: 27, stress 20.9252719897
# it: 29, stress 21.0359648554
# it: 35, stress 20.4424189423
# it: 25, stress 22.4071477969
# it: 28, stress 24.0524677118
# it: 36, stress 20.3676623961
# it: 30, stress 20.9742511526
# [Parallel(n_jobs=8)]: Done   2 out of   8 | elapsed:    0.2s remaining:    0.7s
# it: 29, stress 24.0067737604
# it: 28, stress 20.8239626712
# it: 37, stress 20.2963513007
# it: 29, stress 20.7246221405
# it: 26, stress 22.2657549262
# it: 38, stress 20.2282641444
# it: 31, stress 20.9175258527
# it: 32, stress 20.8653885131
# it: 30, stress 20.6261397543
# it: 30, stress 23.9623073294
# it: 27, stress 22.1298410905
# it: 33, stress 20.8174528909
# it: 39, stress 20.1631897187
# it: 31, stress 23.9188117869
# it: 40, stress 20.1009280122
# it: 34, stress 20.7733445635
# it: 28, stress 21.9991450816
# it: 31, stress 20.5273258664
# it: 32, stress 23.8760511449
# it: 32, stress 20.4278765007
# it: 29, stress 21.8734161435
# it: 35, stress 20.7326982395
# it: 41, stress 20.0412906594
# it: 33, stress 20.3286543143
# it: 33, stress 23.8338128793
# it: 34, stress 20.2307882033
# it: 30, stress 21.7524099126
# it: 36, stress 20.6951547951
# it: 34, stress 23.7919101004
# it: 42, stress 19.9841010018
# it: 35, stress 20.135054966
# it: 31, stress 21.6358866953
# it: 37, stress 20.6603581515
# it: 38, stress 20.6279522701
# it: 35, stress 23.7501822881
# it: 32, stress 21.5236114462
# it: 43, stress 19.9291938338
# it: 36, stress 20.0418593674
# it: 44, stress 19.8764149022
# it: 33, stress 21.4153548103
# it: 39, stress 20.5975787855
# it: 36, stress 23.7084940225
# it: 37, stress 19.9513651571
# it: 45, stress 19.8256202256
# it: 40, stress 20.5688761397
# it: 34, stress 21.3108946886
# it: 38, stress 19.8635966359
# it: 37, stress 23.6667316175
# it: 41, stress 20.5414814224
# it: 46, stress 19.7766752948
# it: 35, stress 21.2100179194
# it: 42, stress 20.5150362485
# it: 39, stress 19.7784990651
# it: 38, stress 23.6247981832
# it: 47, stress 19.7294542082
# it: 40, stress 19.6959729758
# it: 36, stress 21.1125217963
# it: 48, stress 19.6838387891
# it: 39, stress 23.5826082133
# it: 43, stress 20.489197529
# it: 41, stress 19.6158938402
# it: 49, stress 19.6397177243
# it: 37, stress 21.0182152516
# it: 44, stress 20.4636525812
# it: 42, stress 19.5381236306
# it: 40, stress 23.5400831813
# it: 50, stress 19.5969857578
# it: 45, stress 20.4381358276
# it: 41, stress 23.4971497315
# it: 38, stress 20.9269196204
# it: 46, stress 20.4124423869
# it: 43, stress 19.4625178092
# it: 51, stress 19.5555429614
# it: 44, stress 19.3889296815
# it: 42, stress 23.4537417216
# it: 47, stress 20.3864337391
# it: 39, stress 20.8384689635
# it: 43, stress 23.409806393
# it: 52, stress 19.5152940984
# it: 45, stress 19.3172131986
# it: 48, stress 20.3600330984
# it: 53, stress 19.4761480857
# it: 46, stress 19.2472248379
# it: 49, stress 20.3332119918
# it: 40, stress 20.7527099738
# it: 44, stress 23.3653132674
# it: 47, stress 19.1788249364
# it: 54, stress 19.4380175522
# it: 45, stress 23.3202625391
# it: 41, stress 20.6695015252
# it: 48, stress 19.1118787055
# it: 46, stress 23.2746889933
# it: 50, stress 20.3059724681
# it: 55, stress 19.4008184874
# it: 42, stress 20.5887139365
# it: 56, stress 19.3644699646
# it: 49, stress 19.0462570699
# it: 51, stress 20.2783298555
# it: 47, stress 23.2286588664
# it: 52, stress 20.2502994397
# it: 57, stress 19.328893925
# it: 43, stress 20.5102280354
# it: 48, stress 23.1822600918
# it: 50, stress 18.9818374199
# it: 53, stress 20.2218882546
# it: 58, stress 19.294015004
# it: 49, stress 23.1355891071
# it: 51, stress 18.9185043308
# it: 54, stress 20.1930915334
# it: 44, stress 20.4339340995
# it: 52, stress 18.8561502806
# it: 59, stress 19.2597603837
# it: 55, stress 20.16389258
# it: 45, stress 20.3597307469
# it: 50, stress 23.0887381682
# it: 60, stress 19.2260596557
# it: 56, stress 20.13426471
# it: 53, stress 18.7946763814
# it: 51, stress 23.0417859449
# it: 61, stress 19.1928446819
# it: 46, stress 20.2875238313
# it: 54, stress 18.7339931247
# it: 52, stress 22.9947923052
# it: 57, stress 20.1041741264
# it: 47, stress 20.2172253885
# it: 55, stress 18.6740211303
# it: 48, stress 20.148752662
# it: 53, stress 22.9477967762
# it: 62, stress 19.160049442
# it: 54, stress 22.9008195444
# it: 58, stress 20.0735829176
# it: 49, stress 20.0820272286
# it: 63, stress 19.1276098623
# it: 55, stress 22.8538638606
# it: 56, stress 18.6146918767
# it: 64, stress 19.095463621
# it: 50, stress 20.0169742335
# it: 65, stress 19.0635499317
# it: 59, stress 20.0424516514
# it: 51, stress 19.9535217397
# it: 56, stress 22.8069189825
# it: 66, stress 19.0318093077
# it: 60, stress 20.0107412762
# it: 52, stress 19.8916001905
# it: 57, stress 18.5559483772
# it: 57, stress 22.7599631179
# it: 67, stress 19.0001833166
# it: 53, stress 19.8311419828
# it: 61, stress 19.9784142108
# it: 58, stress 18.4977457524
# it: 58, stress 22.7129660924
# it: 62, stress 19.9454346313
# it: 54, stress 19.7720811449
# it: 68, stress 18.968614338
# it: 63, stress 19.9117680469
# it: 55, stress 19.7143531146
# it: 59, stress 18.4400516397
# it: 59, stress 22.6658916484
# it: 64, stress 19.8773803108
# it: 69, stress 18.937045345
# it: 60, stress 18.38284637
# it: 60, stress 22.6186993837
# it: 56, stress 19.6578946096
# it: 61, stress 22.5713463848
# it: 61, stress 18.3261228407
# it: 65, stress 19.8422362321
# it: 70, stress 18.9054197361
# it: 62, stress 22.5237886106
# it: 57, stress 19.6026435832
# it: 66, stress 19.8062979525
# it: 67, stress 19.7695232282
# it: 71, stress 18.8736812523
# it: 62, stress 18.2698860227
# it: 58, stress 19.5485392555
# it: 63, stress 22.4759820611
# it: 59, stress 19.4955222101
# it: 68, stress 19.7318637297
# it: 63, stress 18.2141520604
# it: 64, stress 22.4278837354
# it: 60, stress 19.4435345429
# it: 72, stress 18.8417740229
# it: 61, stress 19.392520046
# it: 69, stress 19.6932635002
# it: 65, stress 22.3794523604
# it: 70, stress 19.6537750236
# it: 73, stress 18.8096427847
# it: 66, stress 22.3306488618
# it: 64, stress 18.1589469528
# it: 62, stress 19.3424244105
# it: 74, stress 18.777233319
# it: 67, stress 22.281436557
# it: 71, stress 19.6134501552
# it: 65, stress 18.1043048464
# it: 75, stress 18.7444931358
# it: 63, stress 19.293195427
# it: 66, stress 18.0502660103
# it: 76, stress 18.7113202566
# it: 67, stress 17.9968746013
# it: 72, stress 19.5722244288
# it: 68, stress 22.2317810477
# it: 77, stress 18.6776443906
# it: 68, stress 17.9441763519
# it: 64, stress 19.2447831647
# it: 69, stress 22.1816497848
# it: 65, stress 19.1971401101
# it: 73, stress 19.5300092976
# it: 70, stress 22.1310112489
# it: 69, stress 17.8922163234
# it: 74, stress 19.4867033147
# it: 78, stress 18.6434527577
# it: 71, stress 22.0798336623
# it: 66, stress 19.1502212509
# it: 75, stress 19.4421921527
# it: 79, stress 18.6087188304
# it: 76, stress 19.3963493795
# it: 72, stress 22.0280831325
# it: 70, stress 17.8410368586
# it: 73, stress 21.9757211376
# it: 67, stress 19.1039840953
# it: 80, stress 18.5734158899
# it: 77, stress 19.3490383655
# it: 78, stress 19.3001161355
# it: 74, stress 21.9227013244
# it: 71, stress 17.7906758447
# it: 72, stress 17.7411653672
# it: 68, stress 19.0583886235
# it: 81, stress 18.53752445
# it: 75, stress 21.8689657042
# it: 69, stress 19.0133971749
# it: 79, stress 19.2494408091
# it: 82, stress 18.5010321227
# it: 80, stress 19.1968852456
# it: 73, stress 17.6925307951
# it: 70, stress 18.9689742801
# it: 76, stress 21.8144405584
# it: 83, stress 18.4639329272
# it: 71, stress 18.9250864522
# it: 81, stress 19.1423592243
# it: 77, stress 21.7590327856
# it: 74, stress 17.6447903043
# it: 78, stress 21.7026281207
# it: 82, stress 19.0858385063
# it: 79, stress 21.6450936024
# it: 84, stress 18.4262261266
# it: 72, stress 18.8817019536
# it: 75, stress 17.5979548146
# it: 80, stress 21.5862873822
# it: 73, stress 18.8387905547
# it: 83, stress 19.0273910308
# it: 84, stress 18.9671847993
# it: 76, stress 17.5520282903
# it: 85, stress 18.9054683454
# it: 74, stress 18.796323301
# it: 85, stress 18.3879147541
# it: 81, stress 21.5260782284
# it: 77, stress 17.5070083414
# it: 82, stress 21.4643733339
# it: 75, stress 18.7542722995
# it: 78, stress 17.4628870503
# it: 76, stress 18.7126105355
# it: 86, stress 18.8425310395
# it: 86, stress 18.3490040209
# it: 87, stress 18.7786611918
# it: 79, stress 17.4196519484
# it: 87, stress 18.3094997801
# it: 83, stress 21.4011466311
# it: 80, stress 17.3772870679
# it: 88, stress 18.7141161648
# it: 81, stress 17.3357740001
# it: 77, stress 18.671311723
# it: 88, stress 18.269407177
# it: 89, stress 18.6491080683
# it: 84, stress 21.3364552734
# it: 82, stress 17.2950928984
# it: 78, stress 18.6303501923
# it: 89, stress 18.2287295448
# it: 85, stress 21.2704352648
# it: 90, stress 18.5838013581
# it: 79, stress 18.5897008125
# it: 90, stress 18.1874675534
# it: 86, stress 21.2032778987
# it: 83, stress 17.2552233756
# it: 80, stress 18.5493389462
# it: 91, stress 18.5183170734
# it: 92, stress 18.4527397803
# it: 81, stress 18.5092404322
# it: 91, stress 18.145618561
# it: 93, stress 18.3871250108
# it: 87, stress 21.1351980229
# it: 82, stress 18.4693815887
# it: 84, stress 17.2161452563
# it: 94, stress 18.3215061867
# it: 92, stress 18.1031760864
# it: 85, stress 17.1778391562
# it: 88, stress 21.0664060802
# it: 95, stress 18.255900664
# it: 83, stress 18.4297392332
# it: 93, stress 18.0601292821
# it: 96, stress 18.1903148379
# it: 86, stress 17.1402868752
# it: 89, stress 20.9970901188
# it: 94, stress 18.0164622488
# it: 90, stress 20.9274077203
# it: 84, stress 18.3902907107
# it: 91, stress 20.857484659
# it: 97, stress 18.1247483644
# it: 92, stress 20.787416895
# it: 87, stress 17.1034716004
# it: 95, stress 17.9721529667
# it: 98, stress 18.0591975919
# it: 85, stress 18.3510139272
# it: 96, stress 17.9271714953
# it: 99, stress 17.9936582992
# it: 93, stress 20.7172736259
# it: 86, stress 18.3118873794
# it: 88, stress 17.0673779289
# it: 94, stress 20.6471003867
# it: 97, stress 17.8814768687
# it: 89, stress 17.0319917264
# it: 95, stress 20.5769221055
# it: 87, stress 18.27289018
# it: 98, stress 17.8350116944
# it: 88, stress 18.2340020716
# it: 90, stress 16.9972998447
# it: 96, stress 20.5067465148
# it: 99, stress 17.7876927223
# it: 91, stress 16.9632897268
# it: 97, stress 20.4365684133
# it: 89, stress 18.1952034293
# it: 98, stress 20.3663750318
# it: 92, stress 16.9299489268
# it: 90, stress 18.1564752493
# it: 99, stress 20.2961522383
# it: 91, stress 18.1177991245
# it: 93, stress 16.897264575
# it: 94, stress 16.8652228141
# it: 92, stress 18.0791572117
# it: 95, stress 16.833808234
# it: 93, stress 18.0405321926
# it: 94, stress 18.001907238
# it: 96, stress 16.8020361694
# it: 95, stress 17.9632659817
# it: 97, stress 16.7702065769
# it: 96, stress 17.9245925122
# it: 98, stress 16.7386012729
# it: 97, stress 17.8858713855
# it: 99, stress 16.7072114392
# it: 98, stress 17.8470876576
# it: 99, stress 17.8082269216
# [Parallel(n_jobs=8)]: Done   8 out of   8 | elapsed:    1.1s finished

# %%
nonZeroList = [listImg_short[p] for p in nonZeroIndex]
scatter_img(X, nonZeroList, 'MDS.png')
# Out:
# /Users/andrey/anaconda/envs/py34/lib/python3.4/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
